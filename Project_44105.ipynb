# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***1. Import all the important and useful libraries.***

# %%
# Import important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***2. Open the GESDB Project Data in csv format in Jupyter Lab.***

# %%
#  I opened the csv file in the jupyter notebook and use the head command for convenient reading.
velos = pd.read_csv('GESDB_Project_Data_all.csv')
velos.head()
# By the head command, we can show only the first five-row data.
# Out:
#    ID Data Source                                 Project/Plant Name  \
# 0   1       GESDB  Ponale (Riva del Garda Ledro) Hydroelectric Po...
# 1   2       GESDB               Urdiceto Hydroelectric Power Station
# 2   3       GESDB                   Rocky River Pumped Storage Plant
# 3   4       GESDB       Etzelwerk Pumped Hydro Storage Power Station
# 4   5       GESDB                          Skhodnenskaya Hydro Plant
#
#         Status  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# 0  Operational             80000                                      0.0
# 1  Operational              7200                                      0.0
# 2  Operational             29000                                      0.0
# 3  Operational            135000                                      0.0
# 4  Operational             30000                                      0.0
#
#    Storage Capacity (kWh)  \
# 0                     0.0
# 1                     0.0
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***3. Delete or remove the unnecessary empty data from the original dataset.***

# %%
# We can remove 'null/empty' column data from the original data set by this 'dropana' command.
v1 = velos.dropna(how='all', axis=1)
v1.head()
# In the original data, we have 119 columns but now we have only 67 useful columns.
# Out:
#    ID Data Source                                 Project/Plant Name  \
# 0   1       GESDB  Ponale (Riva del Garda Ledro) Hydroelectric Po...
# 1   2       GESDB               Urdiceto Hydroelectric Power Station
# 2   3       GESDB                   Rocky River Pumped Storage Plant
# 3   4       GESDB       Etzelwerk Pumped Hydro Storage Power Station
# 4   5       GESDB                          Skhodnenskaya Hydro Plant
#
#         Status  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# 0  Operational             80000                                      0.0
# 1  Operational              7200                                      0.0
# 2  Operational             29000                                      0.0
# 3  Operational            135000                                      0.0
# 4  Operational             30000                                      0.0
#
#    Storage Capacity (kWh)  \
# 0                     0.0
# 1                     0.0
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***4. Find the information of the type of the dataset like integer, object and float.***

# %%
# We can find information on our given dataset by the info() command.
v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 67 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   ID                                                                      1693 non-null   int64
#  1   Data Source                                                             1693 non-null   object
#  2   Project/Plant Name                                                      1693 non-null   object
#  3   Status                                                                  1692 non-null   object
#  4   Rated Power (kW)                                                        1693 non-null   int64
#  5   Discharge Duration at Rated Power (hrs)                                 1693 non-null   float64
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***5. Find the number of rows and columns.***

# %%
# If we want to find how big is the given dataset then, we can use the 'shape' command to show only row and column numbers.
v1.shape
# We have 1693 rows and 67 rows in our data set.
# Out:
# (1693, 67)

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***6. Statistical values for a given dataset like maximum, minimum, standard, average etc.***

# %%
# Used describe function to find out all the statistical values for the given dataset.
v1.describe()
# I used this command to find out the maximum, minimum, and mean(average) values of the dataset.
# Out:
#                 ID  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# count  1693.000000      1.693000e+03                              1693.000000
# mean    847.000000      1.133010e+05                                12.323006
# std     488.871319      3.232414e+05                               348.841332
# min       1.000000      0.000000e+00                                 0.000000
# 25%     424.000000      7.500000e+01                                 0.000000
# 50%     847.000000      1.000000e+03                                 1.600000
# 75%    1270.000000      2.000000e+04                                 4.000000
# max    1693.000000      4.000000e+06                             14310.330000
#
#        Storage Capacity (kWh)     Latitude    Longitude  Number of Subsystems  \
# count            1.693000e+03  1693.000000  1693.000000                1693.0
# mean             1.055010e+06    33.957242   -18.918356                   1.0
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***7. Find the memory usage of the given database.***

# %%
# We can find the memory usage by this command.
v1.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 67 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   ID                                                                      1693 non-null   int64
#  1   Data Source                                                             1693 non-null   object
#  2   Project/Plant Name                                                      1693 non-null   object
#  3   Status                                                                  1692 non-null   object
#  4   Rated Power (kW)                                                        1693 non-null   int64
#  5   Discharge Duration at Rated Power (hrs)                                 1693 non-null   float64
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***8. Set all the given data into an array.***

# %%
# We can set the dataset into the array. All the rows and columns are set into the array.
X = v1.iloc[:,0:118].values
X
# Out:
# array([[1, 'GESDB',
#         'Ponale (Riva del Garda Ledro) Hydroelectric Power Station', ...,
#         'Pumped hydro storage', 'Open-loop PHS', 80000],
#        [2, 'GESDB', 'Urdiceto Hydroelectric Power Station', ...,
#         'Pumped hydro storage', 'Open-loop PHS', 7200],
#        [3, 'GESDB', 'Rocky River Pumped Storage Plant', ...,
#         'Pumped hydro storage', 'Open-loop PHS', 29000],
#        ...,
#        [1691, 'GESDB', 'Rabbit Hill Energy Storage Project', ...,
#         'Lithium-ion battery', nan, 9900],
#        [1692, 'GESDB',
#         'Cat Creek Energy & Water Storage Renewable Power Station', ...,
#         'Pumped hydro storage', 'Open-loop PHS', 720000],
#        [1693, 'GESDB',
#         "New York's First Completed Solar Energy Storage Project", ...,
#         'Lithium-ion battery', nan, 490]], dtype=object)

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***9. Set the all data according to the country.***

# %%
# We can filter the given dataset for the only country by this command.
v1['Country']
# Out:
# 0               Italy
# 1               Spain
# 2       United States
# 3         Switzerland
# 4              Russia
#             ...
# 1688    United States
# 1689    United States
# 1690    United States
# 1691    United States
# 1692    United States
# Name: Country, Length: 1693, dtype: object

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***10. Find the data for the United Kingdom from the data set because my task for this project is to analyse the data of the United Kingdom and compare this data to the different countries.***

# %%
# We can get United KIngdom's data from the given data of all specific countries.
Country = v1[v1['Country']=='United Kingdom']
Country.head()
# Out:
#       ID Data Source                                 Project/Plant Name  \
# 156  157       GESDB                             Dinorwig Power Station
# 252  253       GESDB  EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...
# 295  296       GESDB                     Horse Island Microgrid Project
# 397  398       GESDB  Slough Zero-Carbon Homes Community Energy Storage
# 453  454       GESDB                      Isle of Muck Microgrid System
#
#           Status  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# 156  Operational           1728000                                     5.00
# 252  Operational            400000                                     0.00
# 295  Operational                12                                     5.00
# 397  Operational                75                                     1.00
# 453  Operational                45                                     3.67
#
#      Storage Capacity (kWh)  \
# 156              8640000.00
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***11. Delete or remove all the unnecessary empty data from the data of the United Kingdom.***

# %%
# We can delete or remove empty data from the United Kingdom by this command.
UK = Country.dropna(how='all', axis=1)
UK.head()
# Out:
#       ID Data Source                                 Project/Plant Name  \
# 156  157       GESDB                             Dinorwig Power Station
# 252  253       GESDB  EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...
# 295  296       GESDB                     Horse Island Microgrid Project
# 397  398       GESDB  Slough Zero-Carbon Homes Community Energy Storage
# 453  454       GESDB                      Isle of Muck Microgrid System
#
#           Status  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# 156  Operational           1728000                                     5.00
# 252  Operational            400000                                     0.00
# 295  Operational                12                                     5.00
# 397  Operational                75                                     1.00
# 453  Operational                45                                     3.67
#
#      Storage Capacity (kWh)  \
# 156              8640000.00
# ...

# %%
# We have 40 rows and 57 columns in this dataset.
UK.shape
# Out:
# (40, 57)

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***12. Top most important data for the United Kingdom.***

# %%
# All the statistical data for the United Kingdom like maximum, minimum, mean, and standard.
UK.describe()
# By this command, we can see that 25% powerplant has 2kw rated power, 1hr discharge duration, and 100kwh storage capacity we can also see the description for the 50% and 75%.
# Out:
#                 ID  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# count    40.000000      4.000000e+01                                40.000000
# mean    836.400000      9.032970e+04                                 3.587750
# std     371.830386      2.927451e+05                                 4.312244
# min     157.000000      2.000000e+00                                 0.000000
# 25%     477.750000      5.000000e+01                                 1.000000
# 50%     830.500000      3.250000e+02                                 2.000000
# 75%    1135.250000      3.125000e+03                                 5.000000
# max    1577.000000      1.728000e+06                                22.000000
#
#        Storage Capacity (kWh)   Latitude  Longitude  Number of Subsystems  \
# count            4.000000e+01  40.000000  40.000000                  40.0
# mean             5.629961e+05  53.941209  -2.698857                   1.0
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***13. The biggest powerplant in the United Kingdom and its location.***

# %%
# Find the latitude and Longitude of the biggest powerplant in the United Kingdom.
Location = UK[['Project/Plant Name', 'Rated Power (kW)', 'Latitude', 'Longitude' ]]
Location_For_laegestplant = Location.nlargest(1,'Rated Power (kW)')
Location_For_laegestplant
# Out:
#          Project/Plant Name  Rated Power (kW)  Latitude  Longitude
# 156  Dinorwig Power Station           1728000  53.13405      -4.11

# %%
### Location of the largest powerplant 'Dinorwig Power Station into map'

# %%
# I used geopandas for the import map for Europe.
print('Pandas version: ', pd.__version__)
print('Geopandas version: ', gpd.__version__)
# Out:
# Pandas version:  1.4.3
# Geopandas version:  0.9.0

# %%
# Set latitude and longitude into a geometry coordinate system.
from platform import python_version
print(python_version())
gdf = gpd.GeoDataFrame(Location_For_laegestplant, geometry=gpd.points_from_xy(Location_For_laegestplant.Longitude, Location_For_laegestplant.Latitude))
gdf
# Out:
# 3.9.7
#          Project/Plant Name  Rated Power (kW)  Latitude  Longitude  \
# 156  Dinorwig Power Station           1728000  53.13405      -4.11
#
#                       geometry
# 156  POINT (-4.11000 53.13405)

# %%
# Here is the location of the largest powerplant in the United Kingdom. 
world1 = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax2 = world1[world1.continent == 'Europe' ].plot(color='white', edgecolor='blue', figsize=(55,4))
gdf.plot(ax=ax2, color='red')
plt.show()
# I show only one important power location because the area of the United Kingdom is too small for indicating all 40 power plants.

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***14. We can see the location, postal code and URL of the powerplants.***

# %%
# Location, postal code and URL of the power plant.
URL = UK[['Project/Plant Name','State/Province', 'Postal Code', 'URL']]
URL
# Out:
#                                      Project/Plant Name  \
# 156                              Dinorwig Power Station
# 252   EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...
# 295                      Horse Island Microgrid Project
# 397   Slough Zero-Carbon Homes Community Energy Storage
# 453                       Isle of Muck Microgrid System
# 459                         Orkney Storage Park Project
# 473                      Northern Powergrid CLNR ESS2-1
# 474                        Northern Powergrid CLNR EES1
# 475                      Northern Powergrid CLNR ESS2-2
# 476                      Northern Powergrid CLNR ESS3-1
# 477                      Northern Powergrid CLNR EES3-2
# 478                      Northern Powergrid CLNR ESS3-3
# 600   Slepe Farm: Solar + 250 kWh storage - Farm Pow...
# 606                             Smarter Network Storage
# 679   Highview Pilot Plant - Relocated to University...
# 681   University of Birmingham Cryogenic Energy Stor...
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***15. Status of the powerplants.***

# %%
# We can filter the status of the powerplant by this command.
Status = UK[['Project/Plant Name', 'Status' ]]
Status
# We can see the stats of the individual powerplant whether they are operational, de-commissioned, Announced/Never Built, and Under Construction.
# Out:
#                                      Project/Plant Name                 Status
# 156                              Dinorwig Power Station            Operational
# 252   EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...            Operational
# 295                      Horse Island Microgrid Project            Operational
# 397   Slough Zero-Carbon Homes Community Energy Storage            Operational
# 453                       Isle of Muck Microgrid System            Operational
# 459                         Orkney Storage Park Project            Operational
# 473                      Northern Powergrid CLNR ESS2-1            Operational
# 474                        Northern Powergrid CLNR EES1            Operational
# 475                      Northern Powergrid CLNR ESS2-2            Operational
# 476                      Northern Powergrid CLNR ESS3-1            Operational
# 477                      Northern Powergrid CLNR EES3-2            Operational
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***16. Filter the owner of this given powerplant.***

# %%
# We can filter the owners of the individual powerplants by this command.
Owner_of_plant = UK[['Project/Plant Name', 'Owner(s)']]
Owner_of_plant
# Out:
#                                      Project/Plant Name  \
# 156                              Dinorwig Power Station
# 252   EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...
# 295                      Horse Island Microgrid Project
# 397   Slough Zero-Carbon Homes Community Energy Storage
# 453                       Isle of Muck Microgrid System
# 459                         Orkney Storage Park Project
# 473                      Northern Powergrid CLNR ESS2-1
# 474                        Northern Powergrid CLNR EES1
# 475                      Northern Powergrid CLNR ESS2-2
# 476                      Northern Powergrid CLNR ESS3-1
# 477                      Northern Powergrid CLNR EES3-2
# 478                      Northern Powergrid CLNR ESS3-3
# 600   Slepe Farm: Solar + 250 kWh storage - Farm Pow...
# 606                             Smarter Network Storage
# 679   Highview Pilot Plant - Relocated to University...
# 681   University of Birmingham Cryogenic Energy Stor...
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***17. Filter the subsystem of the storage device for the given powerplant.***

# %%
# we can filter the technology of the storage device of the given country of the UK.
Storage_technology = UK[['Project/Plant Name', 'Subsystems.0.Storage Device.Technology Broad Category']]
Storage_technology
# Out:
#                                      Project/Plant Name  \
# 156                              Dinorwig Power Station
# 252   EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...
# 295                      Horse Island Microgrid Project
# 397   Slough Zero-Carbon Homes Community Energy Storage
# 453                       Isle of Muck Microgrid System
# 459                         Orkney Storage Park Project
# 473                      Northern Powergrid CLNR ESS2-1
# 474                        Northern Powergrid CLNR EES1
# 475                      Northern Powergrid CLNR ESS2-2
# 476                      Northern Powergrid CLNR ESS3-1
# 477                      Northern Powergrid CLNR EES3-2
# 478                      Northern Powergrid CLNR ESS3-3
# 600   Slepe Farm: Solar + 250 kWh storage - Farm Pow...
# 606                             Smarter Network Storage
# 679   Highview Pilot Plant - Relocated to University...
# 681   University of Birmingham Cryogenic Energy Stor...
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***18. Filter storage device technology for the given dataset.***

# %%
# We can filter the technology of the storage device technology Mid-type of the given country of UK.
Technology_Mid_Type = UK[['Project/Plant Name', 'Subsystems.0.Storage Device.Technology Mid-Type']]
Technology_Mid_Type
# Out:
#                                      Project/Plant Name  \
# 156                              Dinorwig Power Station
# 252   EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...
# 295                      Horse Island Microgrid Project
# 397   Slough Zero-Carbon Homes Community Energy Storage
# 453                       Isle of Muck Microgrid System
# 459                         Orkney Storage Park Project
# 473                      Northern Powergrid CLNR ESS2-1
# 474                        Northern Powergrid CLNR EES1
# 475                      Northern Powergrid CLNR ESS2-2
# 476                      Northern Powergrid CLNR ESS3-1
# 477                      Northern Powergrid CLNR EES3-2
# 478                      Northern Powergrid CLNR ESS3-3
# 600   Slepe Farm: Solar + 250 kWh storage - Farm Pow...
# 606                             Smarter Network Storage
# 679   Highview Pilot Plant - Relocated to University...
# 681   University of Birmingham Cryogenic Energy Stor...
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***19. Filter the technology subtype for the given power plant.***

# %%
# we can filter the technology of the storage device technology Sub-type of the given country of UK.
Technology_sub_Type = UK[['Project/Plant Name', 'Subsystems.0.Storage Device.Technology Sub-Type']]
Technology_sub_Type
# Out:
#                                      Project/Plant Name  \
# 156                              Dinorwig Power Station
# 252   EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...
# 295                      Horse Island Microgrid Project
# 397   Slough Zero-Carbon Homes Community Energy Storage
# 453                       Isle of Muck Microgrid System
# 459                         Orkney Storage Park Project
# 473                      Northern Powergrid CLNR ESS2-1
# 474                        Northern Powergrid CLNR EES1
# 475                      Northern Powergrid CLNR ESS2-2
# 476                      Northern Powergrid CLNR ESS3-1
# 477                      Northern Powergrid CLNR EES3-2
# 478                      Northern Powergrid CLNR ESS3-3
# 600   Slepe Farm: Solar + 250 kWh storage - Farm Pow...
# 606                             Smarter Network Storage
# 679   Highview Pilot Plant - Relocated to University...
# 681   University of Birmingham Cryogenic Energy Stor...
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***20. Find the data of maximum and minimum powerplant based on the given country.***

# %%
# Here is the code for the maximum and the minimum value for the specific data.
def min_max_values(col):
  
    top = UK[col].idxmax()
    top_obs = pd.DataFrame(UK.loc[top])
    
    bottom = UK[col].idxmin()
    bot_obs = pd.DataFrame(UK.loc[bottom])
    
    min_max_obs = pd.concat([top_obs, bot_obs], axis = 1)
    return min_max_obs

# %%
# Here we can see that the powerplant with id 156 has maximum power it is 1728000kw and id 717 has minimum power of 2kw.
min_max_values('Rated Power (kW)')
# We can show different data also for the maximum and minimum values.
# Out:
#                                                                                                   156  \
# ID                                                                                                157
# Data Source                                                                                     GESDB
# Project/Plant Name                                                             Dinorwig Power Station
# Status                                                                                    Operational
# Rated Power (kW)                                                                              1728000
# Discharge Duration at Rated Power (hrs)                                                           5.0
# Storage Capacity (kWh)                                                                      8640000.0
# Applications.Bulk Energy Services (General Ener...             Electric Energy Time Shift (Arbitrage)
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***21. Rated power of given dataset in descending order and its Graphical representation.***

# %%
# We can filter Rated power(kW) from the given country UK.
Rated_Power = UK[['Project/Plant Name', 'Rated Power (kW)' ]]
Rated_Power_descending = Rated_Power.sort_values(by='Rated Power (kW)', ascending = False)
Rated_Power_descending
# Out:
#                                      Project/Plant Name  Rated Power (kW)
# 156                              Dinorwig Power Station           1728000
# 828                              Cruachan Power Station            440000
# 252   EFDA JET Fusion Flywheel - 400 MWs Supplied Fr...            400000
# 1065                Ffestiniog Pumped Hydro Power Plant            360000
# 1186  330 MW - Gaelectric Compressed Air Energy Stor...            330000
# 1067               Foyers Pumped Storage Power Station             300000
# 1105                             UK National Grid - RES             20000
# 956          AES Kilroot Advancion Energy Storage Array             10000
# 606                             Smarter Network Storage              6000
# 1341  Pre-Commercial Liquid Air Energy Storage Techn...              5000
# 474                        Northern Powergrid CLNR EES1              2500
# 459                         Orkney Storage Park Project              2000
# ...

# %%
# We can represent the Rated power Vs power plant name by the graphical representation of the bar graph.
plt.subplots(figsize=(7,5), dpi=150)
plt.bar(Rated_Power['Project/Plant Name'], Rated_Power['Rated Power (kW)'], color='slateblue', width = 0.5)
plt.title('Plant name vs Rated power' , fontsize=10, fontweight='bold')
plt.xlabel('Project/Plant Name' , fontsize=10 , fontweight ='bold')
plt.ylabel('Rated Power (kW)' , fontsize=10 , fontweight='bold')
plt.xticks(rotation = 90, fontsize = 8)
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***22. Graphical representation of top 5 and smallest 5 powerplants according to rated power.***

# %%
Highest_5 =Rated_Power.nlargest(5, 'Rated Power (kW)')
Smallest_5 = Rated_Power.nsmallest(5, 'Rated Power (kW)')
pd.merge(Highest_5,Smallest_5, how='outer')
# Here the first five rows indicate top storage capacity and the last five rows indicate the lowest Rated Power (kW).
# Out:
#                                   Project/Plant Name  Rated Power (kW)
# 0                     Srisailam Pumped Hydro Storage           1670000
# 1        Sardar Sarovar Pumped Storage Power Station           1450000
# 2     Tehri Pumped Storage Hydroelectric Power Plant           1000000
# 3   Purulia Pumped Storage Hydroelectric Power Plant            900000
# 4  Nagarjuna Sagar Pumped Hydro Station Tail Pond...            700000
# 5              GAT College 30 kW Imergy Flow Battery                30
# 6           Gram Power Khareda Lakshmipura Microgrid                40
# 7      Sun-carrier Omega Net Zero Building in Bhopal                45
# 8                        L&T/eCamion-Anna University               125
# 9             Clique Solar Solar Thermal HVAC System               175

# %%
# Graphical representation for the top 5 powerplants according to the rated power. 
plt.subplots(figsize=(8.5, 3),dpi=125)
plt.subplot(1, 2, 1)
plt.bar(Highest_5['Project/Plant Name'], Highest_5['Rated Power (kW)'], color='sienna', width = 0.5)
plt.xlabel('Plant Name' , fontsize=8 , fontweight='bold')
plt.ylabel('Top 5 Rated Power (kW)' , fontsize=8 , fontweight='bold')
plt.xticks(rotation = 90, fontsize = 8)
plt.title('Plant name vs Rated power' , fontsize=8, fontweight='bold')

# Graphical representation for the smallest 5 powerplants according to the rated power. 
plt.subplot(1, 2, 2)
plt.bar(Smallest_5['Project/Plant Name'], Smallest_5['Rated Power (kW)'], color='seagreen', width = 0.5)
plt.xlabel('Plant Name' , fontsize=8 , fontweight='bold')
plt.ylabel('Lowest 5 Rated Power (kW)' , fontsize=8 , fontweight='bold')
plt.xticks(rotation = 90, fontsize = 8)
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***23. Filter discharge duration according to plant name in descending order.***

# %%
# We can filter the discharge duration of the UK's powerplant.
Discharge_Duration = UK[['Project/Plant Name', 'Discharge Duration at Rated Power (hrs)' ]]
Discharge_Duration_descending = Discharge_Duration.sort_values(by='Discharge Duration at Rated Power (hrs)', ascending = False)
Discharge_Duration_descending
# Out:
#                                      Project/Plant Name  \
# 828                              Cruachan Power Station
# 1194                    Gigha Wind Farm Battery Project
# 831   5 kW / 40 kWh - redT Wokingham Development Fac...
# 679   Highview Pilot Plant - Relocated to University...
# 681   University of Birmingham Cryogenic Energy Stor...
# 1186  330 MW - Gaelectric Compressed Air Energy Stor...
# 1117                        Lerwick Power Station - NGK
# 1065                Ffestiniog Pumped Hydro Power Plant
# 156                              Dinorwig Power Station
# 1576                        Flat Holm Microgrid Project
# 295                      Horse Island Microgrid Project
# 1461                   Isentropic Demonstration Project
# 1364                             RedT-Southwest England
# 1221                       Isle of Rum Microgrid System
# 453                       Isle of Muck Microgrid System
# 717                                   Welsh House-Tesla
# ...

# %%
# Here are the two different maximum and minimum data based on the discharged duration.
min_max_values('Discharge Duration at Rated Power (hrs)')
# Powerplant with id 828 has maximum discharge duration 22hrs and id 252 has a minimum discharge duration is 0hrs.
# All available data for this maximum and minimum category.
# Out:
#                                                                                                   828  \
# ID                                                                                                829
# Data Source                                                                                     GESDB
# Project/Plant Name                                                             Cruachan Power Station
# Status                                                                                    Operational
# Rated Power (kW)                                                                               440000
# Discharge Duration at Rated Power (hrs)                                                          22.0
# Storage Capacity (kWh)                                                                      9680000.0
# Applications.Bulk Energy Services (General Ener...             Electric Energy Time Shift (Arbitrage)
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***24. Graphical representation of discharge duration according to plant name.***

# %%
# I used the seaborn command to draw the graph.
sns.set(color_codes=True)
sns.distplot(Discharge_Duration['Discharge Duration at Rated Power (hrs)'])
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Discharge Duration at Rated Power (hrs)', ylabel='Density'>

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***25. Filter the data of Storage Capacity according to the plant name.***

# %%
# We can filter the dataset according to storage capacity from the given dataset.
Storage_Capacity = UK[['Project/Plant Name', 'Storage Capacity (kWh)' ]]
Storage_Capacity_ascending = Storage_Capacity.sort_values(by='Storage Capacity (kWh)', ascending = False)
# I remove the last three powerplants who has 0 storage capacity because it is an unnecessary graphical representation.
Storage_Capacity_1  = Storage_Capacity_ascending.iloc[:-3 , :]
Storage_Capacity_1
# Out:
#                                      Project/Plant Name  \
# 828                              Cruachan Power Station
# 156                              Dinorwig Power Station
# 1065                Ffestiniog Pumped Hydro Power Plant
# 1186  330 MW - Gaelectric Compressed Air Energy Stor...
# 1341  Pre-Commercial Liquid Air Energy Storage Techn...
# 606                             Smarter Network Storage
# 1117                        Lerwick Power Station - NGK
# 1461                   Isentropic Demonstration Project
# 474                        Northern Powergrid CLNR EES1
# 956          AES Kilroot Advancion Energy Storage Array
# 679   Highview Pilot Plant - Relocated to University...
# 681   University of Birmingham Cryogenic Energy Stor...
# 1194                    Gigha Wind Farm Battery Project
# 765                                   Batwind - Statoil
# 848   EPSRC Grid Connected Energy Storage Research D...
# 874   Western Power Distribution (WPD) Battery Stora...
# ...

# %%
# Collect the data as per maximum and minimum Storage Capacity.
min_max_values('Storage Capacity (kWh)')
# Here the top storage capacity is 9680000kwh and the lowest storage capacity is 0kwh.
# Out:
#                                                                                                   828  \
# ID                                                                                                829
# Data Source                                                                                     GESDB
# Project/Plant Name                                                             Cruachan Power Station
# Status                                                                                    Operational
# Rated Power (kW)                                                                               440000
# Discharge Duration at Rated Power (hrs)                                                          22.0
# Storage Capacity (kWh)                                                                      9680000.0
# Applications.Bulk Energy Services (General Ener...             Electric Energy Time Shift (Arbitrage)
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***26. Graphical representation of powerplant according to storage capacity is not possible to visualise the data so, I will divide this data into the top 5 and smallest 5 powerplants.***

# %%
# We can draw a graph for storage capacity Vs powerplant name by this command.
plt.subplots(figsize=(7,5),dpi=100)
plt.bar(Storage_Capacity['Project/Plant Name'], Storage_Capacity['Storage Capacity (kWh)'], color='r', width = 0.5)
plt.title('Plant name vs Storage Capacity' , fontsize=10, fontweight='bold')
plt.xlabel('Project/Plant Name' , fontsize=10 , fontweight ='bold')
plt.ylabel('Storage Capacity (kWh)' , fontsize=10 , fontweight='bold')
plt.xticks(rotation = 90, fontsize=8)
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***27. Filter top 5 and smallest 5 powerplants according to storage capacity.***

# %%
Highest_5 = Storage_Capacity_1.nlargest(5, 'Storage Capacity (kWh)')
Smallest_5 = Storage_Capacity_1.nsmallest(5, 'Storage Capacity (kWh)')
df1 = pd.merge(Highest_5,Smallest_5, how='outer')
df1
# Her first five rows indicate top storage capacity and the last five rows indicate the lowest storage capacity.
# Out:
#                                   Project/Plant Name  Storage Capacity (kWh)
# 0                             Cruachan Power Station               9680000.0
# 1                             Dinorwig Power Station               8640000.0
# 2                Ffestiniog Pumped Hydro Power Plant               2160000.0
# 3  330 MW - Gaelectric Compressed Air Energy Stor...               1980000.0
# 4  Pre-Commercial Liquid Air Energy Storage Techn...                 15000.0
# 5                                  Welsh House-Tesla                     7.0
# 6       Diesel Generator Solar + Storage Replacement                    22.0
# 7                        Flat Holm Microgrid Project                    25.0
# 8  5 kW / 40 kWh - redT Wokingham Development Fac...                    40.0
# 9                     Horse Island Microgrid Project                    60.0

# %%
# We draw a graphical representation of the top 5 Rated Power because it was difficult to read data from the all rated power. After all, the range of the power is so large.
plt.subplots(figsize=(8.5, 3),dpi=150)

plt.subplot(1, 2, 1)
plt.bar(Highest_5['Project/Plant Name'], Highest_5['Storage Capacity (kWh)'], color='b', width = 0.2)
plt.title('Plant name vs Storage Capacity (kWh)' , fontsize = 8, fontweight='bold')
plt.xlabel('Project/Plant Name' , fontsize=8 , fontweight ='bold')
plt.ylabel(' Top 5 Storage Capacity (kWh)' , fontsize=8 , fontweight ='bold')
plt.xticks(rotation = 90, fontsize=8)

plt.subplot(1, 2, 2)
plt.bar(Smallest_5['Project/Plant Name'], Smallest_5['Storage Capacity (kWh)'], color='olive', width = 0.2)
plt.xlabel('Project/Plant Name' , fontsize=8 , fontweight='bold')
plt.ylabel('Smallest 10 Storage Capacity (kWh)' , fontsize=8 , fontweight='bold')
plt.xticks(rotation = 90, fontsize = 8)
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***28. Now I compare the United Kingdom's data to my home country India.***

# %%
# Filter the Indian powerplant from the dataset.
D = v1[v1['Country']=='India']
D.head()
# Out:
#       ID Data Source                                 Project/Plant Name  \
# 8      9       GESDB                   Bhira Pumped Storage Hydro Plant
# 98    99       GESDB              Poithan (Jayakwadi Dam) Hydro Station
# 131  132       GESDB                     Srisailam Pumped Hydro Storage
# 178  179       GESDB  Kadamparai Hydroelectric Pumped Storage Power ...
# 217  218       GESDB                 Kadana Hydroelectric Power Station
#
#           Status  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# 8    Operational            150000                                      0.0
# 98   Operational             12000                                      0.0
# 131  Operational           1670000                                      0.0
# 178  Operational            400000                                      0.0
# 217  Operational            240000                                      0.0
#
#      Storage Capacity (kWh)  \
# 8                       0.0
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***29. Remove the unnecessary empty data of India from the given dataset.***

# %%
# Now we compare the United Kingdom's powerplants with India.
India = D.dropna(how='all', axis=1)
India.head()
# Out:
#       ID Data Source                                 Project/Plant Name  \
# 8      9       GESDB                   Bhira Pumped Storage Hydro Plant
# 98    99       GESDB              Poithan (Jayakwadi Dam) Hydro Station
# 131  132       GESDB                     Srisailam Pumped Hydro Storage
# 178  179       GESDB  Kadamparai Hydroelectric Pumped Storage Power ...
# 217  218       GESDB                 Kadana Hydroelectric Power Station
#
#           Status  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# 8    Operational            150000                                      0.0
# 98   Operational             12000                                      0.0
# 131  Operational           1670000                                      0.0
# 178  Operational            400000                                      0.0
# 217  Operational            240000                                      0.0
#
#      Storage Capacity (kWh)  \
# 8                       0.0
# ...

# %%
India.shape
# There are total 21 powerplants with 50 specifications.
# Out:
# (21, 50)

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***30. Location of all the 21 Indian powerplants.***

# %%
# Filter the latitude and longitude according to plants name from the dataset.
Location1  = India[['Project/Plant Name', 'Latitude', 'Longitude' ]]
Location1Location1  = India[['Project/Plant Name', 'Latitude', 'Longitude' ]]
Location1.head()
# Out:
#                                     Project/Plant Name   Latitude  Longitude
# 8                     Bhira Pumped Storage Hydro Plant  18.454833      73.39
# 98               Poithan (Jayakwadi Dam) Hydro Station  19.477921      75.37
# 131                     Srisailam Pumped Hydro Storage  16.073275      78.87
# 178  Kadamparai Hydroelectric Pumped Storage Power ...  11.016844      76.96
# 217                 Kadana Hydroelectric Power Station  23.289591      73.84

# %%
# I used geopandas for indicate the locations.
print('Pandas version: ', pd.__version__)
print('Geopandas version: ', gpd.__version__)
from platform import python_version
print(python_version())
# Out:
# Pandas version:  1.4.3
# Geopandas version:  0.9.0
# 3.9.7

# %%
# Set the latitude and longitude in geometry form.
gdf1 = gpd.GeoDataFrame(Location1, geometry=gpd.points_from_xy(Location1.Longitude, Location1.Latitude))
gdf1.head()
# Out:
#                                     Project/Plant Name   Latitude  Longitude  \
# 8                     Bhira Pumped Storage Hydro Plant  18.454833      73.39
# 98               Poithan (Jayakwadi Dam) Hydro Station  19.477921      75.37
# 131                     Srisailam Pumped Hydro Storage  16.073275      78.87
# 178  Kadamparai Hydroelectric Pumped Storage Power ...  11.016844      76.96
# 217                 Kadana Hydroelectric Power Station  23.289591      73.84
#
#                       geometry
# 8    POINT (73.39000 18.45483)
# 98   POINT (75.37000 19.47792)
# 131  POINT (78.87000 16.07327)
# 178  POINT (76.96000 11.01684)
# 217  POINT (73.84000 23.28959)

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax1 = world[world.continent == 'Asia'].plot(color='white', edgecolor='blue', figsize = (16,16))
gdf1.plot(ax=ax1, color='red')
plt.show()
# Here is the location of the Indian powerplant.

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***31. Stastistical data of the Indian power plant.***

# %%
# We can find the statistical data of powerplant based on maxmimum, minimum, average, 25%, 50% and 75%.
India.describe()
# By this command, we can see that 25% powerplant has 1kw rated power, 0hr discharge duration, and 0kwh storage capacity we can also see the description for the 50% and 75%.
# Out:
#                 ID  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# count    21.000000      2.100000e+01                                21.000000
# mean    834.333333      3.384960e+05                                 5.365238
# std     592.886611      5.059002e+05                                10.606572
# min       9.000000      3.000000e+01                                 0.000000
# 25%     254.000000      1.000000e+03                                 0.000000
# 50%     892.000000      1.000000e+05                                 2.000000
# 75%    1385.000000      4.000000e+05                                 6.000000
# max    1660.000000      1.670000e+06                                48.000000
#
#        Storage Capacity (kWh)   Latitude  Longitude  Number of Subsystems  \
# count            2.100000e+01  21.000000  21.000000                  21.0
# mean             5.933367e+05  21.540780  76.125238                   1.0
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***32. Indian power plants based on the rated power in descending order.***

# %%
# We can  filter Rated power(kw) ffrom the given country UK. 
Rated_Power = India[['Project/Plant Name', 'Rated Power (kW)' ]]
Rated_Power_descending = Rated_Power.sort_values(by='Rated Power (kW)', ascending = False)
Rated_Power_descending
# Out:
#                                      Project/Plant Name  Rated Power (kW)
# 131                      Srisailam Pumped Hydro Storage           1670000
# 891         Sardar Sarovar Pumped Storage Power Station           1450000
# 1095     Tehri Pumped Storage Hydroelectric Power Plant           1000000
# 266    Purulia Pumped Storage Hydroelectric Power Plant            900000
# 1456  Nagarjuna Sagar Pumped Hydro Station Tail Pond...            700000
# 178   Kadamparai Hydroelectric Pumped Storage Power ...            400000
# 253   Ghatghar Pumped Storage Hydroelectric Power Plant            250000
# 217                  Kadana Hydroelectric Power Station            240000
# 8                      Bhira Pumped Storage Hydro Plant            150000
# 1383                           KVK Energy Solar Project            100000
# 1491     Solar Energy Corporation of India (SECI)-100MW            100000
# 1658                                  Diwakar CSP Plant            100000
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***33. Comparision of UK, Indian and US powerplants.***

# %%
US = v1[v1['Country']=='United States']
US.head()
# Out:
#     ID Data Source                     Project/Plant Name       Status  \
# 2    3       GESDB       Rocky River Pumped Storage Plant  Operational
# 11  12       GESDB                    Flatiron Powerplant  Operational
# 26  27       GESDB  Taum Sauk Hydroelectric Power Station  Operational
# 34  35       GESDB             Yards Creek Pumped Storage  Operational
# 39  40       GESDB         Muddy Run Pumped Hydro Storage  Operational
#
#     Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# 2              29000                                      0.0
# 11              8500                                      0.0
# 26            440000                                      8.0
# 34            400000                                      6.0
# 39           1070000                                      0.0
#
#     Storage Capacity (kWh)  \
# 2                      0.0
# 11                     0.0
# 26               3520000.0
# 34               2400000.0
# ...

# %%
US.shape
# There are total 729 powerplants in US.
# Out:
# (729, 67)

# %%
US.describe()
## We can find the statistical data of powerplant based on maxmimum, minimum, average, 25%, 50% and 75%.
# Out:
#                 ID  Rated Power (kW)  Discharge Duration at Rated Power (hrs)  \
# count   729.000000      7.290000e+02                               729.000000
# mean    925.235940      4.496577e+04                                 3.733306
# std     459.858882      2.117540e+05                                11.625004
# min       3.000000      0.000000e+00                                 0.000000
# 25%     520.000000      2.800000e+01                                 0.480000
# 50%     934.000000      2.250000e+02                                 2.000000
# 75%    1307.000000      2.000000e+03                                 4.670000
# max    1693.000000      3.003000e+06                               250.000000
#
#        Storage Capacity (kWh)    Latitude   Longitude  Number of Subsystems  \
# count            7.290000e+02  729.000000  729.000000                 729.0
# mean             5.151723e+05   36.863260 -104.878471                   1.0
# ...

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***34. Location of top 10 powerplants of United States.***

# %%
# Find the latitude and Longitude of the biggest powerplant in the US.
Location = US[['Project/Plant Name', 'Rated Power (kW)', 'Latitude', 'Longitude' ]]
Location_For_laegestplant = Location.nlargest(10,'Rated Power (kW)')
Location_For_laegestplant.head()
# Out:
#                                      Project/Plant Name  Rated Power (kW)  \
# 166   Bath County Pumped Storage Station - Dominion ...           3003000
# 82                             Ludington Pumped Storage           1872000
# 114               Raccoon Mountain Pumped Storage Plant           1652000
# 1418              Eagle Mountain Pumped Storage Project           1300000
# 75                         Castaic Pumped-Storage Plant           1247000
#
#        Latitude  Longitude
# 166   38.198392     -79.81
# 82    43.894481     -86.44
# 114   35.019816     -85.37
# 1418  33.713331    -115.40
# 75    34.654833    -118.78

# %%
# I used geopandas for the import map for North America.
print('Pandas version: ', pd.__version__)
print('Geopandas version: ', gpd.__version__)
# Out:
# Pandas version:  1.4.3
# Geopandas version:  0.9.0

# %%
# Set latitude and longitude into a geometry coordinate system.
from platform import python_version
print(python_version())
gdf = gpd.GeoDataFrame(Location_For_laegestplant, geometry=gpd.points_from_xy(Location_For_laegestplant.Longitude, Location_For_laegestplant.Latitude))
gdf.head()
# Out:
# 3.9.7
#                                      Project/Plant Name  Rated Power (kW)  \
# 166   Bath County Pumped Storage Station - Dominion ...           3003000
# 82                             Ludington Pumped Storage           1872000
# 114               Raccoon Mountain Pumped Storage Plant           1652000
# 1418              Eagle Mountain Pumped Storage Project           1300000
# 75                         Castaic Pumped-Storage Plant           1247000
#
#        Latitude  Longitude                     geometry
# 166   38.198392     -79.81   POINT (-79.81000 38.19839)
# 82    43.894481     -86.44   POINT (-86.44000 43.89448)
# 114   35.019816     -85.37   POINT (-85.37000 35.01982)
# 1418  33.713331    -115.40  POINT (-115.40000 33.71333)
# 75    34.654833    -118.78  POINT (-118.78000 34.65483)

# %%
# Here is the location of the largest 10 powerplant in the United States. 
world1 = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax2 = world1[world1.continent == 'North America' ].plot(color='white', edgecolor='blue', figsize=(55,8))
gdf.plot(ax=ax2, color='red')
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***35. Comparision between the United Kingdom, Indian, and US powerplants based on the total rated power and maximum rated power.***

# %%
# We can find the total power of the three country by sum().
uk_total_power = sum(UK['Rated Power (kW)'])
print(uk_total_power) 
india_total_power = sum(India['Rated Power (kW)'])
print(india_total_power) 
us_total_power = sum(US['Rated Power (kW)'])
print(us_total_power) 

# We can find the maximum power of the three country by max().
uk_max_power = UK['Rated Power (kW)'].max()
print(uk_max_power)
india_max_power = India['Rated Power (kW)'].max()
print(india_max_power)
us_max_power = US['Rated Power (kW)'].max()
print(us_max_power)


# I choose two different tasks for making comparisons, Total and maximum rated power for the UK, India ans US.
# Out:
# 3613188
# 7108415
# 32780047
# 1728000
# 1670000
# 3003000

# %%
# Graphical representation of both countries based on the total rated power.
Country = ['United Kingdom','India', 'United States']
Total_Power = [uk_total_power, india_total_power, us_total_power ]
Max_Power = [uk_max_power, india_max_power, us_max_power]
plt.subplots(figsize=(8.5, 3),dpi=125)

plt.subplot(1, 2, 1) 
plt.bar(Country, Total_Power, color = 'purple')
plt.title('Total Power Vs Country(kW)', fontsize= 10, fontweight ='bold')
plt.xlabel('Country', fontsize=10 , fontweight ='bold')
plt.ylabel('Total_Power (kW)', fontsize=10 , fontweight ='bold')

# Graphical representation of both countries based on the maximum rated power.
plt.subplot(1, 2, 2)
plt.bar(Country, Max_Power, color = 'navy')
plt.title('Maximum Power(kW) Vs Country', fontsize= 10, fontweight ='bold')
plt.xlabel('Country', fontsize=10 , fontweight ='bold')
plt.ylabel('Max_Power (kW)', fontsize=10 , fontweight ='bold')
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***36. Comparision between the United Kingdom, Indian, and US powerplants based on the total storage capasity and maximum storage capasity.***

# %%
# We can find the total storage capasity of the both country by sum().
uk_total_storage_capacity = sum(UK['Storage Capacity (kWh)'])
print(uk_total_storage_capacity )
india_total_storage_capacity = sum(India['Storage Capacity (kWh)'])
print(india_total_storage_capacity)
us_total_storage_capacity = sum(US['Storage Capacity (kWh)'])
print(us_total_storage_capacity)


# We can find the maximum storage capasity of the three country by sum().
uk_max_storage_capacity = UK['Storage Capacity (kWh)'].max()
print(uk_max_storage_capacity)
india_max_storage_capacity = India['Storage Capacity (kWh)'].max()
print(india_max_storage_capacity)
us_max_storage_capacity = US['Storage Capacity (kWh)'].max()
print(us_max_storage_capacity)
# I choose two different tasks for making comparisons, Total and maximum storage capasity for the UK, India and US.
# Out:
# 22519843.299999997
# 12460070.15
# 375560577.80999994
# 9680000.0
# 5600000.0
# 87120000.0

# %%
# Graphical representation of countries based on total storage capasity.
Total_Storage_Capacity = [uk_total_storage_capacity, india_total_storage_capacity, us_total_storage_capacity]
Max_Storage_Capacity = [uk_max_storage_capacity, india_max_storage_capacity, us_max_storage_capacity]
plt.subplots(figsize=(8.5, 3),dpi=125)
plt.subplot(1, 2, 1) 

plt.bar(Country, Total_Storage_Capacity, color = 'gold')
plt.title('Total Storage Capacity Vs Country', fontsize= 10, fontweight ='bold')
plt.xlabel('Country', fontsize=10 , fontweight ='bold')
plt.ylabel('Total Storage Capacity(kwh)', fontsize=10 , fontweight ='bold')

# Graphical representation of countries based on maximum storage capasity.
plt.subplot(1, 2, 2)
plt.bar(Country, Max_Storage_Capacity, color='magenta')
plt.title('Maximum Storage Capacity Vs Country', fontsize= 9, fontweight ='bold')
plt.xlabel('Country', fontsize=10 , fontweight ='bold')
plt.ylabel('Maximum Storage Capacity (kwh)', fontsize=10 , fontweight ='bold')
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'> ***37. Comparision between the United Kingdom, Indian, and US powerplants based on the total discharge duration and maximum discharge duration.***

# %%
# We can find the total discharge duration of countries by sum().
uk_total_discharge_duration = sum(UK['Discharge Duration at Rated Power (hrs)'])
print(uk_total_discharge_duration)
india_total_discharge_duration = sum(India['Discharge Duration at Rated Power (hrs)'])
print(india_total_discharge_duration)
us_total_discharge_duration = sum(US['Discharge Duration at Rated Power (hrs)'])
print(us_total_discharge_duration)

# We can find the maximum discharge dutation of the countries by sum().
uk_max_discharge_duration= UK['Discharge Duration at Rated Power (hrs)'].max()
print(uk_max_discharge_duration)
india_max_discharge_duration = India['Discharge Duration at Rated Power (hrs)'].max()
print(india_max_discharge_duration)
us_max_discharge_duration = US['Discharge Duration at Rated Power (hrs)'].max()
print(us_max_discharge_duration)
# I choose two different tasks for making comparisons, Total and maximum discharge duration for the UK, India and US.
# Out:
# 143.51
# 112.67
# 2721.5799999999995
# 22.0
# 48.0
# 250.0

# %%
# Graphical representation of countries based on total storage capasity.
Total_Discharge_Duration = [uk_total_discharge_duration, india_total_discharge_duration, us_total_discharge_duration]
Max_Discharge_Duration = [uk_max_discharge_duration, india_max_discharge_duration, us_max_discharge_duration]
plt.subplots(figsize=(8.5, 3),dpi=125)

plt.subplot(1, 2, 1) 
plt.bar(Country, Total_Discharge_Duration, color='g')
plt.title('Total Discharge Duration Vs Country', fontsize= 10, fontweight ='bold')
plt.xlabel('Country', fontsize=10 , fontweight ='bold')
plt.ylabel('Total Discharge Duration (hrs)', fontsize=10 , fontweight ='bold')

# Graphical representation of countries based on the maximum discharge duration.
plt.subplot(1, 2, 2)
plt.bar(Country, Max_Discharge_Duration, color='brown')
plt.title('Maximum Discharge duration Vs Country', fontsize= 10, fontweight ='bold')
plt.xlabel('Country', fontsize=10 , fontweight ='bold')
plt.ylabel('Maximum Discharge Duration (hrs)', fontsize=10 , fontweight ='bold')
plt.show()

# %% [markdown]
# ## <span style='color:brown'><span style='font-family:Georgia'>Small feedback for module 'Data Science with Python',
# So, here is my small project work. I hope you like it. I try to use all commands and instructions which has been given in our class. Thank you so much Professor Lustermann for teaching us data science with python. We enjoy this module and now we have basic ideas about data science and python language. If next winter semester, there will be any module related to computer language, AI or Machine language then I will join that module.
# Thank you so much for your valuable time.
